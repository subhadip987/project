# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("GlobalWeatherRepository.csv")

# %%
df.head()
# Out:
#        country     location_name  latitude  longitude        timezone  \
# 0  Afghanistan             Kabul     34.52      69.18      Asia/Kabul
# 1      Albania            Tirana     41.33      19.82   Europe/Tirane
# 2      Algeria           Algiers     36.76       3.05  Africa/Algiers
# 3      Andorra  Andorra La Vella     42.50       1.52  Europe/Andorra
# 4       Angola            Luanda     -8.84      13.23   Africa/Luanda
#
#    last_updated_epoch      last_updated  temperature_celsius  \
# 0          1715849100  2024-05-16 13:15                 26.6
# 1          1715849100  2024-05-16 10:45                 19.0
# 2          1715849100  2024-05-16 09:45                 23.0
# 3          1715849100  2024-05-16 10:45                  6.3
# 4          1715849100  2024-05-16 09:45                 26.0
#
#    temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 0                    79.8  Partly Cloudy  ...                8.4
# ...

# %%
df.shape
# Out:
# (123941, 41)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123941 entries, 0 to 123940
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   country                       123941 non-null  object
#  1   location_name                 123941 non-null  object
#  2   latitude                      123941 non-null  float64
#  3   longitude                     123941 non-null  float64
#  4   timezone                      123941 non-null  object
#  5   last_updated_epoch            123941 non-null  int64
#  6   last_updated                  123941 non-null  object
#  7   temperature_celsius           123941 non-null  float64
#  8   temperature_fahrenheit        123941 non-null  float64
#  9   condition_text                123941 non-null  object
#  10  wind_mph                      123941 non-null  float64
#  11  wind_kph                      123941 non-null  float64
# ...

# %%
df.describe()
# Out:
#             latitude      longitude  last_updated_epoch  temperature_celsius  \
# count  123941.000000  123941.000000        1.239410e+05        123941.000000
# mean       19.192779      21.993802        1.743428e+09            21.641757
# std        24.426819      65.792941        1.590943e+07             9.561140
# min       -41.300000    -175.200000        1.715849e+09           -29.800000
# 25%         3.750000      -6.836100        1.729676e+09            16.300000
# 50%        17.250000      23.240000        1.743412e+09            24.100000
# 75%        40.400000      50.580000        1.757231e+09            28.100000
# max        64.150000     179.220000        1.770970e+09            49.200000
#
#        temperature_fahrenheit       wind_mph       wind_kph    wind_degree  \
# count           123941.000000  123941.000000  123941.000000  123941.000000
# mean                70.956909       8.070885      12.992421     169.254274
# ...

# %%
print("Number of Rows:", df.shape[0])
print("Number of Columns:", df.shape[1])
print("\nColumn Names:")
for col in df.columns:
    print("-", col)
# Out:
# Number of Rows: 123941
# Number of Columns: 41
#
# Column Names:
# - country
# - location_name
# - latitude
# - longitude
# - timezone
# - last_updated_epoch
# - last_updated
# - temperature_celsius
# - temperature_fahrenheit
# - condition_text
# - wind_mph
# - wind_kph
# - wind_degree
# - wind_direction
# - pressure_mb
# - pressure_in
# - precip_mm
# - precip_in
# - humidity
# - cloud
# - feels_like_celsius
# - feels_like_fahrenheit
# - visibility_km
# - visibility_miles
# - uv_index
# - gust_mph
# - gust_kph
# - air_quality_Carbon_Monoxide
# - air_quality_Ozone
# - air_quality_Nitrogen_dioxide
# - air_quality_Sulphur_dioxide
# - air_quality_PM2.5
# - air_quality_PM10
# - air_quality_us-epa-index
# - air_quality_gb-defra-index
# - sunrise
# - sunset
# - moonrise
# - moonset
# - moon_phase
# - moon_illumination

# %%
weather_vars = {
    "Temperature Related": [col for col in df.columns if "temp" in col.lower()],
    "Wind Related": [col for col in df.columns if "wind" in col.lower()],
    "Precipitation Related": [col for col in df.columns if "rain" in col.lower() or "precip" in col.lower()],
    "Humidity Related": [col for col in df.columns if "humid" in col.lower()]
}

weather_vars
# Out:
# {'Temperature Related': ['temperature_celsius', 'temperature_fahrenheit'],
#  'Wind Related': ['wind_mph', 'wind_kph', 'wind_degree', 'wind_direction'],
#  'Precipitation Related': ['precip_mm', 'precip_in'],
#  'Humidity Related': ['humidity']}

# %%
df.select_dtypes(include=['float64', 'int64']).mean().sort_values(ascending=False).head(5)
# Out:
# last_updated_epoch             1.743428e+09
# pressure_mb                    1.014065e+03
# air_quality_Carbon_Monoxide    4.778103e+02
# wind_degree                    1.692543e+02
# feels_like_fahrenheit          7.257266e+01
# dtype: float64

# %%
if 'country' in df.columns:
    print("🌍 Total Countries Covered:", df['country'].nunique())

if 'city' in df.columns:
    print("🏙️ Total Cities Covered:", df['city'].nunique())
# Out:
# 🌍 Total Countries Covered: 211

# %%
pip install streamlit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
